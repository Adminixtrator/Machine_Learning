# %%
# DATA ANALYSIS BEGINS..

# Importing the necessary libraries..
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data.csv')
data.head(11)
# Out:
#     instant     dteday  yr  mnth  holiday  weekday  workingday  casual  \
# 0         1   1/1/2011   0     1        1        6           0     331
# 1         2   1/2/2011   0     1        0        0           0     131
# 2         3   1/3/2011   0     1        0        1           1     120
# 3         4   1/4/2011   0     1        0        2           1     108
# 4         5   1/5/2011   0     1        0        3           1      82
# 5         6   1/6/2011   0     1        0        4           1      88
# 6         7   1/7/2011   0     1        0        5           1     148
# 7         8   1/8/2011   0     1        0        6           0      68
# 8         9   1/9/2011   0     1        0        0           0      54
# 9        10  1/10/2011   0     1        0        1           1      41
# 10       11  1/11/2011   0     1        0        2           1      43
#
#     registered  count  powerCon
# 0          654    985     29.87
# 1          670    801     15.10
# ...

# %%
data.drop(['instant','weekday'], axis=1, inplace=True)
data1 = data.groupby(['workingday','powerCon']).max().head(51)
data1
# Out:
#                          dteday  yr  mnth  holiday  casual  registered  count
# workingday powerCon
# 0          9.06       4/10/2011   0     4        0    1188        1707   2895
#            9.18        3/6/2011   0     3        0     114         491    605
#            9.20       5/27/2012   1     5        0    3283        3308   6591
#            9.24       8/14/2011   0     8        0    1338        2482   3820
#            9.32       9/16/2012   1     9        0    2166        5167   7333
#            9.33       8/19/2012   1     8        0    1208        3341   4549
#            9.70       7/10/2011   0     7        0    1743        3138   4881
#            9.72      12/23/2012   1    12        0     408        2115   2424
#            9.84       7/31/2011   0     7        0    1524        2778   4302
#            9.88       7/29/2012   1     7        0    2153        4444   6597
#            9.94        4/1/2012   1     4        0    2347        3694   6041
# ...

# %%
data = data.groupby(['yr','mnth']).sum().head(12)
#mnth_pred_data = np.array(mnth_pred_data)
a = pd.Series(data.holiday) 
b = pd.Series(data.workingday)
c = pd.Series(data.casual) 
d = pd.Series(data.registered) 
e = pd.Series(data.count)
cols = ['holiday','workingday','casual','registered','count']

mnth_pred_data = pd.DataFrame(a,b,c,d,e, columns=cols)
mnth_pred_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-900857a8985a> in <module>
#       7 e = pd.Series(data.count)
#       8
# ----> 9 mnth_pred_data = pd.DataFrame(a,b,c,d,e, columns=['holiday','workingday','casual','registered','count'])
#      10 mnth_pred_data
#
# TypeError: __init__() got multiple values for argument 'columns'

# %%
# THE MACHINE LEARNING BEGINS..

# Importing the necessary libraries..
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

x, u, y, v = train_test_split(data, label, random_state=0)
pred = KNeighborsRegressor(n_neighbors = 3)

# %%
# Fitting prediction data..
pred.fit(x,y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform')

# %%
data
# Out:
# array([[   1,    0,    1, ...,  331,  654,  985],
#        [   2,    0,    1, ...,  131,  670,  801],
#        [   3,    0,    1, ...,  120, 1229, 1349],
#        ...,
#        [ 729,    1,   12, ...,  159, 1182, 1341],
#        [ 730,    1,   12, ...,  364, 1432, 1796],
#        [ 731,    1,   12, ...,  439, 2290, 2729]], dtype=int64)

# %%
# Enter new data for prediction here..

new_data = ['']
# Out:
# (548, 9)
